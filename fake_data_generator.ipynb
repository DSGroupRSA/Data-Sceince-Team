# %%
import random as random 
import datetime
from faker import Faker
import pandas as pd

# %%
fake = Faker()
provinces = ['Western Cape', 'Northen Cape', 'Eastern Cape', 'Gauteng', 'Limpopo', 'North West', 'Kwazulu Natal', 
             'Free State', 'Mpumalanga']
com_channel = ['WhatsApp', 'call', 'email']
table_columns = ['name','surname','gender','cell_no','phone_no','email','comm_channel', 'address','region',  
                 'reg_date','created_by_id']
sex = ['Male','Female', 'Gay', 'Lesbian', 'Trans-Woman', 'Trans-Man']

# %%
clients = pd.DataFrame(columns=table_columns)

# %%
for i in range(1,31):
    name = str(fake.first_name())
    surname = str(fake.last_name())
    gender = random.choice(sex)
    cell_no = fake.msisdn()
    phone_no = str(fake.phone_number())
    email = str(fake.email())
    comm_channel = random.choice(com_channel)
    address = {'street_no':random.choice([x for x in range(200,700)]), 'street_name':str(fake.street_name()),
                         'suburb':str(fake.city()), 'postal_code':int(fake.postalcode())}
    region = random.choice(provinces)
    reg_date = str(fake.date_time())  #datetime.datetime.now()
    created_bd_id = str(fake.user_name())
    
    row = [name,surname,gender,cell_no,phone_no,email,comm_channel,address,region,reg_date,created_bd_id]
    clients.loc[i] = row
#print row

# %%
clients.head(10)
# Out:
#          name   surname       gender        cell_no              phone_no  \
# 1   Katherine  Bartlett    Trans-Man  2260385405995           00981629996
# 2        Kurt    Thomas       Female  2887406954905     700-859-1837x9011
# 3       James      Beck       Female  9229943058165  1-790-926-1568x72183
# 4        Lisa     Nunez         Male  4347390621446     499.103.4933x7233
# 5     Jessica   Simpson          Gay  4317081055983      445.195.2504x371
# 6    Courtney      Meza  Trans-Woman  4590089612673           04900067591
# 7    Patricia   Shelton  Trans-Woman  6724719566527      574-648-6777x349
# 8      Pamela   Jenkins         Male  5068994579244         (316)172-7381
# 9      Bianca    Wilson  Trans-Woman  9706787621969  1-554-946-7970x09616
# 10    Deborah    Cooper    Trans-Man  3365001340382     (385)968-0135x366
#
#                                email comm_channel  \
# 1           wandaspencer@johnson.com         call
# 2               alice23@valencia.net        email
# 3             tammywhite@hotmail.com     WhatsApp
# 4               zachary27@miller.org     WhatsApp
# 5              angieharris@gmail.com        email
# 6              fisherbrian@yahoo.com         call
# 7   goodwinemma@adams-richardson.com         call
# 8        jessicamartinez@hotmail.com        email
# 9                   kari59@gmail.com     WhatsApp
# 10                  tara85@yahoo.com     WhatsApp
#
#                                               address         region  \
# 1   {u'suburb': u'Grantside', u'street_name': u'Ka...     Mpumalanga
# 2   {u'suburb': u'Taylorfurt', u'street_name': u'J...   Northen Cape
# 3   {u'suburb': u'Salasstad', u'street_name': u'Wa...     Free State
# 4   {u'suburb': u'Gillespieside', u'street_name': ...   Eastern Cape
# 5   {u'suburb': u'New Rogerport', u'street_name': ...     North West
# 6   {u'suburb': u'Lake Lori', u'street_name': u'Jo...        Limpopo
# 7   {u'suburb': u'Lake Joseville', u'street_name':...  Kwazulu Natal
# 8   {u'suburb': u'Deniseport', u'street_name': u'K...   Western Cape
# 9   {u'suburb': u'Lynnmouth', u'street_name': u'Be...     Free State
# 10  {u'suburb': u'Carrollton', u'street_name': u'D...        Limpopo
#
#                reg_date    created_by_id
# 1   1976-05-30 01:55:14     gregorysharp
# 2   2007-05-10 01:36:15       jamescurry
# 3   1999-07-14 04:54:54       megankirby
# 4   2014-02-05 00:17:54   gileselizabeth
# 5   2010-08-17 14:51:18        timothy77
# 6   1988-08-29 11:35:01           eric01
# 7   1985-10-19 07:48:56  lukeblankenship
# 8   2006-05-22 07:50:00         monica04
# 9   2015-04-04 11:39:43         cgilbert
# 10  1989-05-02 23:51:06    michellejames
